# %%
import os
from sklearn.model_selection import train_test_split
datahigh = os.listdir("simple_images/high_traffic")
trainhigh, validhigh = train_test_split(datahigh, test_size=0.2, random_state=1)

# %%
datalow = os.listdir("simple_images/low_traffic")
trainlow, validlow = train_test_split(datalow, test_size=0.2, random_state=1)

# %%
print("Length of High Traffic training dataset  is ", len(trainhigh))
print("Length of High Traffic validation dataset  is ", len(validhigh))
print()
print("Some random images names are")
print(trainhigh[10:20])
print(validhigh[15:25])
# Out:
# Length of High Traffic training dataset  is  160
# Length of High Traffic validation dataset  is  40
#
# Some random images names are
# ['high traffic_98.jpeg', 'huge traffic_3.jpeg', 'huge traffic_26.jpeg', 'high traffic_57.jpeg', 'high traffic_39.jpeg', 'huge traffic_80.jpeg', 'huge traffic_82.jpeg', 'huge traffic_14.jpeg', 'huge traffic_99.jpeg', 'huge traffic_43.jpeg']
# ['huge traffic_25.jpeg', 'huge traffic_62.jpeg', 'high traffic_40.jpeg', 'huge traffic_41.jpeg', 'high traffic_62.jpeg', 'high traffic_55.jpeg', 'high traffic_23.jpeg', 'high traffic_49.jpeg', 'high traffic_94.jpeg', 'high traffic_37.jpeg']

# %%
print("Length of Low Traffic training dataset  is ", len(trainlow))
print("Length of Low Traffic validation dataset  is ", len(validlow))
print()
print("Some random images names are")
print(trainlow[10:20])
print(validlow[15:25])
# Out:
# Length of Low Traffic training dataset  is  172
# Length of Low Traffic validation dataset  is  44
#
# Some random images names are
# ['less traffic_9.jpeg', 'low traffic_51.jpeg', 'low traffic_28.jpeg', 'low traffic_59.png', 'low traffic_16.jpeg', 'low traffic_84.png', 'low traffic_91.jpeg', 'low traffic_58.jpeg', 'low traffic_33.jpeg', 'low traffic_22.jpeg']
# ['less traffic_37.jpeg', 'low traffic_30.png', 'low traffic_15.jpeg', 'less traffic_49.jpeg', 'low traffic_53.png', 'low traffic_54.jpeg', 'less traffic_44.jpeg', 'low traffic_59.jpeg', 'low traffic_73.jpeg', 'low traffic_92.jpeg']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(rescale=1/255)
validation_datagen = ImageDataGenerator(rescale=1/255)

# Flow training images in batches of 120 using train_datagen generator
train_generator = train_datagen.flow_from_directory(
        'split_images/train/',  # This is the source directory for training images
        classes = ['high_traffic', 'low_traffic'],
        target_size=(200, 200),  # All images will be resized to 200x200
        batch_size=120,
        # Use binary labels
        class_mode='binary')

# Flow validation images in batches of 19 using valid_datagen generator
validation_generator = validation_datagen.flow_from_directory(
        'split_images/valid/',  # This is the source directory for training images
        classes = ['high_traffic', 'high_traffic'],
        target_size=(200, 200),  # All images will be resized to 200x200
        batch_size=19,
        # Use binary labels
        class_mode='binary',
        shuffle=False)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow.py in <module>
#      63   try:
# ---> 64     from tensorflow.python._pywrap_tensorflow_internal import *
#      65   # This try catch logic is because there is no bazel equivalent for py_extension.
#
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: The specified module could not be found.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-55158ccbc1f5> in <module>
# ----> 1 from tensorflow.keras.preprocessing.image import ImageDataGenerator
#       2
#       3 # All images will be rescaled by 1./255
#       4 train_datagen = ImageDataGenerator(rescale=1/255)
#       5 validation_datagen = ImageDataGenerator(rescale=1/255)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\__init__.py in <module>
#      39 import sys as _sys
#      40
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      43
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\__init__.py in <module>
#      37 # go/tf-wildcard-import
#      38 # pylint: disable=wildcard-import,g-bad-import-order,g-import-not-at-top
# ---> 39 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
#      40
#      41 from tensorflow.python.eager import context
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow.py in <module>
#      81 for some common reasons and solutions.  Include the entire stack trace
#      82 above this error message when asking for help.""" % traceback.format_exc()
# ---> 83   raise ImportError(msg)
#      84
#      85 # pylint: enable=wildcard-import,g-import-not-at-top,unused-import,line-too-long
#
# ImportError: Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow.py", line 64, in <module>
#     from tensorflow.python._pywrap_tensorflow_internal import *
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: The specified module could not be found.
#
#
# Failed to load the native TensorFlow runtime.
#
# See https://www.tensorflow.org/install/errors
#
# for some common reasons and solutions.  Include the entire stack trace
# above this error message when asking for help.

# %%
pip install tensorflow-gpu
# Out:
# Collecting tensorflow-gpu
#   Downloading tensorflow_gpu-2.4.1-cp38-cp38-win_amd64.whl (370.7 MB)
# Requirement already satisfied: wrapt~=1.12.1 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (1.12.1)
# Requirement already satisfied: absl-py~=0.10 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (0.12.0)
# Requirement already satisfied: astunparse~=1.6.3 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (1.1.2)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (3.7.4.3)
# Requirement already satisfied: grpcio~=1.32.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (1.32.0)
# Requirement already satisfied: six~=1.15.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (1.15.0)
# Requirement already satisfied: termcolor~=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (1.12)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (2.4.0)
# Requirement already satisfied: tensorboard~=2.4 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (2.4.1)
# Requirement already satisfied: h5py~=2.10.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: google-pasta~=0.2 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: gast==0.3.3 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (0.3.3)
# Requirement already satisfied: wheel~=0.35 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (0.35.1)
# Requirement already satisfied: numpy~=1.19.2 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (1.19.2)
# Requirement already satisfied: protobuf>=3.9.2 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (3.15.8)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow-gpu) (1.8.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow-gpu) (50.3.1.post20201107)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\programdata\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow-gpu) (1.29.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\programdata\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow-gpu) (0.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow-gpu) (2.24.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow-gpu) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\programdata\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow-gpu) (1.0.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in c:\programdata\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow-gpu) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow-gpu) (4.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow-gpu) (1.3.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow-gpu) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow-gpu) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow-gpu) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow-gpu) (2020.6.20)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\programdata\anaconda3\lib\site-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow-gpu) (3.1.0)
# Installing collected packages: tensorflow-gpu
# Successfully installed tensorflow-gpu-2.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
conda update conda
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     backports.functools_lru_cache-1.6.4|     pyhd3eb1b0_0           9 KB
#     backports.tempfile-1.0     |     pyhd3eb1b0_1          11 KB
#     conda-4.10.1               |   py38haa95532_1         2.9 MB
#     conda-package-handling-1.7.3|   py38h8cc25b3_1         721 KB
#     ------------------------------------------------------------
#                                            Total:         3.6 MB
#
# The following packages will be UPDATED:
#
#   backports.functoo~                             1.6.1-py_0 --> 1.6.4-pyhd3eb1b0_0
#   conda                                4.9.2-py38haa95532_0 --> 4.10.1-py38haa95532_1
#   conda-package-han~                   1.7.2-py38h76e460a_0 --> 1.7.3-py38h8cc25b3_1
#
# The following packages will be DOWNGRADED:
#
#   backports.tempfile                               1.0-py_1 --> 1.0-pyhd3eb1b0_1
#
#
#
# Downloading and Extracting Packages
#
# backports.tempfile-1 | 11 KB     |            |   0%
# backports.tempfile-1 | 11 KB     | ########## | 100%
# backports.tempfile-1 | 11 KB     | ########## | 100%
#
# Note: you may need to restart the kernel to use updated packages.
# conda-package-handli | 721 KB    |            |   0%
#
# conda-package-handli | 721 KB    | #5         |  16%
# conda-package-handli | 721 KB    | ########## | 100%
# conda-package-handli | 721 KB    | ########## | 100%
#
# conda-4.10.1         | 2.9 MB    |            |   0%
# conda-4.10.1         | 2.9 MB    | ##         |  21%
# conda-4.10.1         | 2.9 MB    | ########## | 100%
# conda-4.10.1         | 2.9 MB    | ########## | 100%
#
# backports.functools_ | 9 KB      |            |   0%
# backports.functools_ | 9 KB      | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
conda update anaconda
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working...
# Warning: 2 possible package resolutions (only showing differing packages):
#   - defaults/noarch::decorator-4.4.2-pyhd3eb1b0_0, defaults/noarch::networkx-2.5.1-pyhd3eb1b0_0
#   - defaults/noarch::decorator-5.0.6-pyhd3eb1b0_0, defaults/noarch::networkx-2.5-py_0done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3
#
#   added / updated specs:
#     - anaconda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2020.07  |           py38_0           6 KB
#     alabaster-0.7.12           |     pyhd3eb1b0_0          16 KB
#     anaconda-custom            |           py38_1          36 KB
#     anaconda-project-0.9.1     |     pyhd3eb1b0_1         215 KB
#     anyio-2.2.0                |   py38haa95532_1         126 KB
#     argon2-cffi-20.1.0         |   py38h2bbff1b_1          49 KB
#     astroid-2.5                |   py38haa95532_1         281 KB
#     astropy-4.2.1              |   py38h2bbff1b_1         5.9 MB
#     async_generator-1.10       |     pyhd3eb1b0_0          23 KB
#     autopep8-1.5.6             |     pyhd3eb1b0_0          43 KB
#     babel-2.9.0                |     pyhd3eb1b0_0         5.5 MB
#     backcall-0.2.0             |     pyhd3eb1b0_0          13 KB
#     backports-1.0              |     pyhd3eb1b0_2         210 KB
#     backports.shutil_get_terminal_size-1.0.0|     pyhd3eb1b0_3          10 KB
#     beautifulsoup4-4.9.3       |     pyha847dfd_0          86 KB
#     bitarray-1.9.2             |   py38h2bbff1b_1         118 KB
#     bleach-3.3.0               |     pyhd3eb1b0_0         113 KB
#     blosc-1.21.0               |       h19a0ad4_0         139 KB
#     bokeh-2.3.1                |   py38haa95532_0         5.9 MB
#     brotli-1.0.9               |       ha925a31_2         332 KB
#     brotlipy-0.7.0             |py38h2bbff1b_1003         412 KB
#     ca-certificates-2021.4.13  |       haa95532_1         115 KB
#     certifi-2020.12.5          |   py38haa95532_0         141 KB
#     cffi-1.14.5                |   py38hcd4344a_0         224 KB
#     chardet-4.0.0              |py38haa95532_1003         211 KB
#     charls-2.2.0               |       h6c2663c_0          82 KB
#     click-7.1.2                |     pyhd3eb1b0_0          64 KB
#     colorama-0.4.4             |     pyhd3eb1b0_0          21 KB
#     comtypes-1.1.9             |py38haa95532_1002         237 KB
#     cryptography-3.4.7         |   py38h71e12ea_0         643 KB
#     cython-0.29.23             |   py38hd77b12b_0         1.7 MB
#     dask-2021.4.0              |     pyhd3eb1b0_0           5 KB
#     dask-core-2021.4.0         |     pyhd3eb1b0_0         670 KB
#     decorator-4.4.2            |     pyhd3eb1b0_0          12 KB
#     defusedxml-0.7.1           |     pyhd3eb1b0_0          23 KB
#     distributed-2021.4.0       |   py38haa95532_0         1.0 MB
#     docutils-0.17              |   py38haa95532_1         695 KB
#     filelock-3.0.12            |     pyhd3eb1b0_1          10 KB
#     flake8-3.9.0               |     pyhd3eb1b0_0         129 KB
#     flask-1.1.2                |     pyhd3eb1b0_0          70 KB
#     fsspec-0.9.0               |     pyhd3eb1b0_0          83 KB
#     gevent-21.1.2              |   py38h2bbff1b_1         1.4 MB
#     giflib-5.2.1               |       h62dcd97_0          81 KB
#     glob2-0.7                  |     pyhd3eb1b0_0          12 KB
#     gmpy2-2.0.8                |   py38h7edee0f_3         145 KB
#     greenlet-1.0.0             |   py38hd77b12b_2          82 KB
#     idna-2.10                  |     pyhd3eb1b0_0          52 KB
#     imagecodecs-2021.3.31      |   py38h5da4933_0         6.1 MB
#     imageio-2.9.0              |     pyhd3eb1b0_0         3.0 MB
#     imagesize-1.2.0            |     pyhd3eb1b0_0           8 KB
#     importlib-metadata-3.10.0  |   py38haa95532_0          34 KB
#     importlib_metadata-3.10.0  |       hd3eb1b0_0          11 KB
#     iniconfig-1.1.1            |     pyhd3eb1b0_0           8 KB
#     ipython-7.22.0             |   py38hd4e2768_0         998 KB
#     ipython_genutils-0.2.0     |     pyhd3eb1b0_1          27 KB
#     ipywidgets-7.6.3           |     pyhd3eb1b0_1         105 KB
#     isort-5.8.0                |     pyhd3eb1b0_0          81 KB
#     itsdangerous-1.1.0         |     pyhd3eb1b0_0          17 KB
#     jinja2-2.11.3              |     pyhd3eb1b0_0         101 KB
#     joblib-1.0.1               |     pyhd3eb1b0_0         208 KB
#     jupyter-packaging-0.7.12   |     pyhd3eb1b0_0          14 KB
#     jupyter_client-6.1.12      |     pyhd3eb1b0_0          88 KB
#     jupyter_console-6.4.0      |     pyhd3eb1b0_0          23 KB
#     jupyter_core-4.7.1         |   py38haa95532_0          85 KB
#     jupyter_server-1.4.1       |   py38haa95532_0         332 KB
#     jupyterlab-3.0.11          |     pyhd3eb1b0_1         3.5 MB
#     jupyterlab_server-2.4.0    |     pyhd3eb1b0_0          37 KB
#     jupyterlab_widgets-1.0.0   |     pyhd3eb1b0_1         109 KB
#     keyring-22.3.0             |   py38haa95532_0          71 KB
#     kiwisolver-1.3.1           |   py38hd77b12b_0          52 KB
#     lazy-object-proxy-1.6.0    |   py38h2bbff1b_0          31 KB
#     lcms2-2.12                 |       h83e58a3_0         454 KB
#     lerc-2.2.1                 |       hd77b12b_0         114 KB
#     libaec-1.0.4               |       h33f27b4_1          31 KB
#     libdeflate-1.7             |       h2bbff1b_5          49 KB
#     libllvm9-9.0.1             |       h21ff451_0          61 KB
#     libspatialindex-1.9.3      |       h6c2663c_0         351 KB
#     libtiff-4.2.0              |       hd0e1b90_0         786 KB
#     libzopfli-1.0.3            |       ha925a31_0         176 KB
#     llvmlite-0.36.0            |   py38h34b8924_4        12.4 MB
#     locket-0.2.1               |   py38haa95532_1          10 KB
#     lxml-4.6.3                 |   py38h9b66d53_0         979 KB
#     lz4-c-1.9.3                |       h2bbff1b_0         131 KB
#     matplotlib-3.3.4           |   py38haa95532_0          27 KB
#     matplotlib-base-3.3.4      |   py38h49ac443_0         5.1 MB
#
# Note: you may need to restart the kernel to use updated packages.    mkl-service-2.3.0          |   py38h196d8e1_0          47 KB
#     mkl_fft-1.3.0              |   py38h46781fe_0         134 KB
#     mock-4.0.3                 |     pyhd3eb1b0_0          29 KB
#     more-itertools-8.7.0       |     pyhd3eb1b0_0          42 KB
#     mpc-1.1.0                  |       h7edee0f_1         260 KB
#     mpfr-4.0.2                 |       h62dcd97_1         1.5 MB
#     mpir-3.0.0                 |       hec2e145_1         1.3 MB
#     mpmath-1.2.1               |   py38haa95532_0         767 KB
#     msgpack-python-1.0.2       |   py38h59b6b97_1          76 KB
#     nbclassic-0.2.6            |     pyhd3eb1b0_0          19 KB
#     nbformat-5.1.3             |     pyhd3eb1b0_0          44 KB
#     networkx-2.5.1             |     pyhd3eb1b0_0         1.1 MB
#     nltk-3.6.1                 |     pyhd3eb1b0_0         988 KB
#     nose-1.3.7                 |  pyhd3eb1b0_1006         128 KB
#     notebook-6.3.0             |   py38haa95532_0         4.4 MB
#     numba-0.53.1               |   py38hf11a4ad_0         3.3 MB
#     numexpr-2.7.3              |   py38hcbcaa1e_0         125 KB
#     openjpeg-2.3.0             |       h5ec785f_1         205 KB
#     openpyxl-3.0.7             |     pyhd3eb1b0_0         159 KB
#     openssl-1.1.1k             |       h2bbff1b_0         4.8 MB
#     packaging-20.9             |     pyhd3eb1b0_0          37 KB
#     pandas-1.2.4               |   py38hd77b12b_0         7.9 MB
#     pandoc-2.12                |       haa95532_0        13.2 MB
#     partd-1.2.0                |     pyhd3eb1b0_0          19 KB
# DEBUG menuinst_win32:__init__(198): Menu: name: 'Anaconda${PY_VER} ${PLATFORM}', prefix: 'C:\ProgramData\Anaconda3', env_name: 'None', mode: 'system', used_mode: 'system'
# DEBUG menuinst_win32:create(323): Shortcut cmd is C:\ProgramData\Anaconda3\python.exe, args are ['C:\\ProgramData\\Anaconda3\\cwp.py', 'C:\\ProgramData\\Anaconda3', 'C:\\ProgramData\\Anaconda3\\python.exe', 'C:\\ProgramData\\Anaconda3\\Scripts\\jupyter-notebook-script.py', '"%USERPROFILE%/"']
# DEBUG menuinst_win32:__init__(198): Menu: name: 'Anaconda${PY_VER} ${PLATFORM}', prefix: 'C:\ProgramData\Anaconda3', env_name: 'None', mode: 'system', used_mode: 'system'
# DEBUG menuinst_win32:create(323): Shortcut cmd is C:\ProgramData\Anaconda3\python.exe, args are ['C:\\ProgramData\\Anaconda3\\cwp.py', 'C:\\ProgramData\\Anaconda3', 'C:\\ProgramData\\Anaconda3\\python.exe', 'C:\\ProgramData\\Anaconda3\\Scripts\\jupyter-notebook-script.py', '"%USERPROFILE%/"']
# DEBUG menuinst_win32:__init__(198): Menu: name: 'Anaconda${PY_VER} ${PLATFORM}', prefix: 'C:\ProgramData\Anaconda3', env_name: 'None', mode: 'system', used_mode: 'system'
# DEBUG menuinst_win32:create(323): Shortcut cmd is C:\ProgramData\Anaconda3\python.exe, args are ['C:\\ProgramData\\Anaconda3\\cwp.py', 'C:\\ProgramData\\Anaconda3', 'C:\\ProgramData\\Anaconda3\\python.exe', 'C:\\ProgramData\\Anaconda3\\Scripts\\jupyter-notebook-script.py', '"%USERPROFILE%/"']
#     path-15.1.2                |   py38haa95532_0          38 KB
#     pathlib2-2.3.5             |   py38haa95532_2          62 KB
#     pexpect-4.8.0              |     pyhd3eb1b0_3          53 KB
#     pickleshare-0.7.5          |  pyhd3eb1b0_1003          13 KB
#     pillow-8.2.0               |   py38h4fa10fc_0         671 KB
#     pip-21.0.1                 |   py38haa95532_0         1.8 MB
#     pkginfo-1.7.0              |   py38haa95532_0          60 KB
#     pluggy-0.13.1              |   py38haa95532_0          34 KB
#     prometheus_client-0.10.1   |     pyhd3eb1b0_0          46 KB
#     prompt-toolkit-3.0.17      |     pyh06a4308_0         256 KB
#     prompt_toolkit-3.0.17      |       hd3eb1b0_0          12 KB
#     psutil-5.8.0               |   py38h2bbff1b_1         350 KB
#     ptyprocess-0.7.0           |     pyhd3eb1b0_2          17 KB
#     py-1.10.0                  |     pyhd3eb1b0_0          76 KB
#     pycodestyle-2.6.0          |     pyhd3eb1b0_0          38 KB
#     pycosat-0.6.3              |   py38h2bbff1b_0          75 KB
#     pydocstyle-6.0.0           |     pyhd3eb1b0_0          35 KB
#     pyerfa-1.7.2               |   py38h2bbff1b_0         301 KB
#     pyflakes-2.2.0             |     pyhd3eb1b0_0          56 KB
#     pygments-2.8.1             |     pyhd3eb1b0_0         703 KB
#     pylint-2.7.4               |   py38haa95532_1         475 KB
#     pyopenssl-20.0.1           |     pyhd3eb1b0_1          49 KB
#     pyparsing-2.4.7            |     pyhd3eb1b0_0          59 KB
#     pysocks-1.7.1              |   py38haa95532_0          31 KB
#     pytest-6.2.3               |   py38haa95532_2         440 KB
#     python-dateutil-2.8.1      |     pyhd3eb1b0_0         221 KB
#     python-libarchive-c-2.9    |     pyhd3eb1b0_1          47 KB
#     pytz-2021.1                |     pyhd3eb1b0_0         181 KB
#     pyyaml-5.4.1               |   py38h2bbff1b_1         151 KB
#     pyzmq-20.0.0               |   py38hd77b12b_1         405 KB
#     qdarkstyle-3.0.2           |     pyhd3eb1b0_0         337 KB
#     qtawesome-1.0.2            |     pyhd3eb1b0_0         760 KB
#     qtconsole-5.0.3            |     pyhd3eb1b0_0          97 KB

# %%
conda update python
# Out:
#     regex-2021.4.4             |   py38h2bbff1b_0         302 KB
#     requests-2.25.1            |     pyhd3eb1b0_0          52 KB
#     rtree-0.9.7                |   py38h2eaa2aa_1          49 KB
#     ruamel_yaml-0.15.100       |   py38h2bbff1b_0         273 KB
#     scikit-image-0.18.1        |   py38hf11a4ad_0         9.1 MB
#     scikit-learn-0.24.1        |   py38hf11a4ad_0         4.8 MB
#     scipy-1.6.2                |   py38h14eb087_0        13.0 MB
#     seaborn-0.11.1             |     pyhd3eb1b0_0         212 KB
#     send2trash-1.5.0           |     pyhd3eb1b0_1          14 KB
#     setuptools-52.0.0          |   py38haa95532_0         726 KB
#     singledispatch-3.6.1       |  pyhd3eb1b0_1001          13 KB
#     snappy-1.1.8               |       h33f27b4_0          80 KB
#     sniffio-1.2.0              |   py38haa95532_1          15 KB
#     snowballstemmer-2.1.0      |     pyhd3eb1b0_0          62 KB
#     sortedcollections-2.1.0    |     pyhd3eb1b0_0          12 KB
#     sortedcontainers-2.3.0     |     pyhd3eb1b0_0          26 KB
#     soupsieve-2.2.1            |     pyhd3eb1b0_0          32 KB
#     sphinxcontrib-applehelp-1.0.2|     pyhd3eb1b0_0          29 KB
#     sphinxcontrib-devhelp-1.0.2|     pyhd3eb1b0_0          23 KB
#     sphinxcontrib-htmlhelp-1.0.3|     pyhd3eb1b0_0          28 KB
#     sphinxcontrib-jsmath-1.0.1 |     pyhd3eb1b0_0           8 KB
#     sphinxcontrib-qthelp-1.0.3 |     pyhd3eb1b0_0          26 KB
#     sphinxcontrib-serializinghtml-1.1.4|     pyhd3eb1b0_0          24 KB
#     sqlalchemy-1.4.7           |   py38h2bbff1b_0         1.8 MB
#     sqlite-3.35.4              |       h2bbff1b_0         761 KB
#     statsmodels-0.12.2         |   py38h2bbff1b_0         8.2 MB
#     sympy-1.8                  |   py38haa95532_0         9.1 MB
#     tbb-2020.3                 |       h74a9793_0         156 KB
#     terminado-0.9.4            |   py38haa95532_0          26 KB
#     testpath-0.4.4             |     pyhd3eb1b0_0          85 KB
#     tifffile-2021.3.31         |     pyhd3eb1b0_1         132 KB
#     toml-0.10.2                |     pyhd3eb1b0_0          20 KB
#     toolz-0.11.1               |     pyhd3eb1b0_0          46 KB
#     tornado-6.1                |   py38h2bbff1b_0         612 KB
#     tqdm-4.59.0                |     pyhd3eb1b0_1          93 KB
#     traitlets-5.0.5            |     pyhd3eb1b0_0          81 KB
#     typing_extensions-3.7.4.3  |     pyha847dfd_0          25 KB
#     ujson-4.0.2                |   py38hd77b12b_0          46 KB
#     urllib3-1.26.4             |     pyhd3eb1b0_0         105 KB
#     vc-14.2                    |       h21ff451_1           8 KB
#     vs2015_runtime-14.27.29016 |       h5e58377_2        1007 KB
#     watchdog-1.0.2             |   py38haa95532_1         104 KB
#     werkzeug-1.0.1             |     pyhd3eb1b0_0         239 KB
#     wheel-0.36.2               |     pyhd3eb1b0_0          33 KB
#     win_inet_pton-1.1.0        |   py38haa95532_0          35 KB
#     wrapt-1.12.1               |   py38he774522_1          49 KB
#     xlrd-2.0.1                 |     pyhd3eb1b0_0          90 KB
#     xlsxwriter-1.3.8           |     pyhd3eb1b0_0         109 KB
#     xlwings-0.23.0             |   py38haa95532_0         859 KB
#     yapf-0.31.0                |     pyhd3eb1b0_0         126 KB
#     zeromq-4.3.3               |       ha925a31_3         4.2 MB
#     zfp-0.5.5                  |       hd77b12b_6         139 KB
#     zict-2.0.0                 |     pyhd3eb1b0_0          10 KB
#     zipp-3.4.1                 |     pyhd3eb1b0_0          15 KB
#     zope.interface-5.3.0       |   py38h2bbff1b_0         300 KB
#     ------------------------------------------------------------
#                                            Total:       168.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/win-64::_anaconda_depends-2020.07-py38_0
#   anyio              pkgs/main/win-64::anyio-2.2.0-py38haa95532_1
#   brotli             pkgs/main/win-64::brotli-1.0.9-ha925a31_2
#   charls             pkgs/main/win-64::charls-2.2.0-h6c2663c_0
#   giflib             pkgs/main/win-64::giflib-5.2.1-h62dcd97_0
#   gmpy2              pkgs/main/win-64::gmpy2-2.0.8-py38h7edee0f_3
#   imagecodecs        pkgs/main/win-64::imagecodecs-2021.3.31-py38h5da4933_0
#   jupyter-packaging  pkgs/main/noarch::jupyter-packaging-0.7.12-pyhd3eb1b0_0
#   jupyter_server     pkgs/main/win-64::jupyter_server-1.4.1-py38haa95532_0
#   jupyterlab_widgets pkgs/main/noarch::jupyterlab_widgets-1.0.0-pyhd3eb1b0_1
#   lcms2              pkgs/main/win-64::lcms2-2.12-h83e58a3_0
#   lerc               pkgs/main/win-64::lerc-2.2.1-hd77b12b_0
#   libaec             pkgs/main/win-64::libaec-1.0.4-h33f27b4_1
#   libdeflate         pkgs/main/win-64::libdeflate-1.7-h2bbff1b_5
#   libllvm9           pkgs/main/win-64::libllvm9-9.0.1-h21ff451_0
#   libzopfli          pkgs/main/win-64::libzopfli-1.0.3-ha925a31_0
#   mpc                pkgs/main/win-64::mpc-1.1.0-h7edee0f_1
#   mpfr               pkgs/main/win-64::mpfr-4.0.2-h62dcd97_1
#   mpir               pkgs/main/win-64::mpir-3.0.0-hec2e145_1
#   nbclassic          pkgs/main/noarch::nbclassic-0.2.6-pyhd3eb1b0_0
#   openjpeg           pkgs/main/win-64::openjpeg-2.3.0-h5ec785f_1
#   ptyprocess         pkgs/main/noarch::ptyprocess-0.7.0-pyhd3eb1b0_2
#   pyerfa             pkgs/main/win-64::pyerfa-1.7.2-py38h2bbff1b_0
#   snappy             pkgs/main/win-64::snappy-1.1.8-h33f27b4_0
#   sniffio            pkgs/main/win-64::sniffio-1.2.0-py38haa95532_1
#   tbb                pkgs/main/win-64::tbb-2020.3-h74a9793_0
#   zfp                pkgs/main/win-64::zfp-0.5.5-hd77b12b_6
#
# The following packages will be UPDATED:
#
#   anaconda-project                               0.8.4-py_0 --> 0.9.1-pyhd3eb1b0_1
#   astroid                                      2.4.2-py38_0 --> 2.5-py38haa95532_1
#   astropy                              4.0.2-py38he774522_0 --> 4.2.1-py38h2bbff1b_1
#   autopep8                                       1.5.4-py_0 --> 1.5.6-pyhd3eb1b0_0
#   babel                                  2.8.1-pyhd3eb1b0_0 --> 2.9.0-pyhd3eb1b0_0
#   backports.shutil_~ pkgs/main/win-64::backports.shutil_ge~ --> pkgs/main/noarch::backports.shutil_get_terminal_size-1.0.0-pyhd3eb1b0_3
#   bitarray                             1.6.1-py38h2bbff1b_0 --> 1.9.2-py38h2bbff1b_1
#   bleach                                         3.2.1-py_0 --> 3.3.0-pyhd3eb1b0_0
#   blosc                                   1.20.1-h7bd577a_0 --> 1.21.0-h19a0ad4_0
#   bokeh                                        2.2.3-py38_0 --> 2.3.1-py38haa95532_0
#   brotlipy                          0.7.0-py38he774522_1000 --> 0.7.0-py38h2bbff1b_1003
#   ca-certificates                              2020.10.14-0 --> 2021.4.13-haa95532_1
#   certifi            pkgs/main/noarch::certifi-2020.6.20-p~ --> pkgs/main/win-64::certifi-2020.12.5-py38haa95532_0
#   cffi                                1.14.3-py38h7a1dbc1_0 --> 1.14.5-py38hcd4344a_0
#   chardet                                   3.0.4-py38_1003 --> 4.0.0-py38haa95532_1003
#   comtypes                                  1.1.7-py38_1001 --> 1.1.9-py38haa95532_1002
#   cryptography                         3.1.1-py38h7a1dbc1_0 --> 3.4.7-py38h71e12ea_0
#   cython                             0.29.21-py38ha925a31_0 --> 0.29.23-py38hd77b12b_0
#   dask                                          2.30.0-py_0 --> 2021.4.0-pyhd3eb1b0_0
#   dask-core                                     2.30.0-py_0 --> 2021.4.0-pyhd3eb1b0_0
#   defusedxml                                     0.6.0-py_0 --> 0.7.1-pyhd3eb1b0_0
#   distributed                         2.30.1-py38haa95532_0 --> 2021.4.0-py38haa95532_0
#   docutils                                      0.16-py38_1 --> 0.17-py38haa95532_1
#   filelock                                      3.0.12-py_0 --> 3.0.12-pyhd3eb1b0_1
#   flake8                                         3.8.4-py_0 --> 3.9.0-pyhd3eb1b0_0
#   fsspec                                         0.8.3-py_0 --> 0.9.0-pyhd3eb1b0_0
#   gevent                              20.9.0-py38he774522_0 --> 21.1.2-py38h2bbff1b_1
#   greenlet                            0.4.17-py38he774522_0 --> 1.0.0-py38hd77b12b_2
#   importlib-metadata pkgs/main/noarch::importlib-metadata-~ --> pkgs/main/win-64::importlib-metadata-3.10.0-py38haa95532_0
#   importlib_metadata                                2.0.0-1 --> 3.10.0-hd3eb1b0_0
#   ipython                             7.19.0-py38hd4e2768_0 --> 7.22.0-py38hd4e2768_0
#   ipython_genutils   pkgs/main/win-64::ipython_genutils-0.~ --> pkgs/main/noarch::ipython_genutils-0.2.0-pyhd3eb1b0_1
#   ipywidgets                                     7.5.1-py_1 --> 7.6.3-pyhd3eb1b0_1
#   isort                                          5.6.4-py_0 --> 5.8.0-pyhd3eb1b0_0
#   jinja2                                        2.11.2-py_0 --> 2.11.3-pyhd3eb1b0_0
#   joblib                                        0.17.0-py_0 --> 1.0.1-pyhd3eb1b0_0
#   jupyter_client                                 6.1.7-py_0 --> 6.1.12-pyhd3eb1b0_0
#   jupyter_console                                6.2.0-py_0 --> 6.4.0-pyhd3eb1b0_0
#   jupyter_core                                 4.6.3-py38_0 --> 4.7.1-py38haa95532_0
#   jupyterlab                                     2.2.6-py_0 --> 3.0.11-pyhd3eb1b0_1
#   jupyterlab_server                              1.2.0-py_0 --> 2.4.0-pyhd3eb1b0_0
#   keyring                                     21.4.0-py38_1 --> 22.3.0-py38haa95532_0
#   kiwisolver                           1.3.0-py38hd77b12b_0 --> 1.3.1-py38hd77b12b_0
#   lazy-object-proxy                    1.4.3-py38he774522_0 --> 1.6.0-py38h2bbff1b_0
#   libtiff                                  4.1.0-h56a325e_1 --> 4.2.0-hd0e1b90_0
#   llvmlite                            0.34.0-py38h1a82afc_4 --> 0.36.0-py38h34b8924_4
#   locket                                       0.2.0-py38_1 --> 0.2.1-py38haa95532_1
#   lxml                                 4.6.1-py38h1350720_0 --> 4.6.3-py38h9b66d53_0
#   lz4-c                                    1.9.2-hf4a77e7_3 --> 1.9.3-h2bbff1b_0
#   matplotlib                                        3.3.2-0 --> 3.3.4-py38haa95532_0
#   matplotlib-base                      3.3.2-py38hba9282a_0 --> 3.3.4-py38h49ac443_0
#   mkl_fft                              1.2.0-py38h45dec08_0 --> 1.3.0-py38h46781fe_0
#   mock                                           4.0.2-py_0 --> 4.0.3-pyhd3eb1b0_0
#   more-itertools                         8.6.0-pyhd3eb1b0_0 --> 8.7.0-pyhd3eb1b0_0
#   mpmath                                       1.1.0-py38_0 --> 1.2.1-py38haa95532_0
#   msgpack-python                       1.0.0-py38h74a9793_1 --> 1.0.2-py38h59b6b97_1
#   nbformat                                       5.0.8-py_0 --> 5.1.3-pyhd3eb1b0_0
#   networkx                                         2.5-py_0 --> 2.5.1-pyhd3eb1b0_0
#   nltk                                             3.5-py_0 --> 3.6.1-pyhd3eb1b0_0
#   nose                  pkgs/main/win-64::nose-1.3.7-py38_2 --> pkgs/main/noarch::nose-1.3.7-pyhd3eb1b0_1006
#   notebook                                     6.1.4-py38_0 --> 6.3.0-py38haa95532_0
#   numba                               0.51.2-py38hf9181ef_1 --> 0.53.1-py38hf11a4ad_0
#   numexpr                              2.7.1-py38h25d0782_0 --> 2.7.3-py38hcbcaa1e_0
#   openpyxl                                       3.0.5-py_0 --> 3.0.7-pyhd3eb1b0_0
#   openssl                                 1.1.1h-he774522_0 --> 1.1.1k-h2bbff1b_0
#   packaging                                       20.4-py_0 --> 20.9-pyhd3eb1b0_0
#   pandas                               1.1.3-py38ha925a31_0 --> 1.2.4-py38hd77b12b_0
#   pandoc                                    2.11-h9490d1a_0 --> 2.12-haa95532_0
#   partd                                          1.1.0-py_0 --> 1.2.0-pyhd3eb1b0_0
#   path                                        15.0.0-py38_0 --> 15.1.2-py38haa95532_0
#   pathlib2                                     2.3.5-py38_0 --> 2.3.5-py38haa95532_2
#   pexpect            pkgs/main/win-64::pexpect-4.8.0-py38_0 --> pkgs/main/noarch::pexpect-4.8.0-pyhd3eb1b0_3
#   pickleshare        pkgs/main/win-64::pickleshare-0.7.5-p~ --> pkgs/main/noarch::pickleshare-0.7.5-pyhd3eb1b0_1003
#   pillow                               8.0.1-py38h4fa10fc_0 --> 8.2.0-py38h4fa10fc_0
#   pip                                 20.2.4-py38haa95532_0 --> 21.0.1-py38haa95532_0
#   pkginfo                              1.6.1-py38haa95532_0 --> 1.7.0-py38haa95532_0
#   prometheus_client                              0.8.0-py_0 --> 0.10.1-pyhd3eb1b0_0
#   prompt-toolkit                                 3.0.8-py_0 --> 3.0.17-pyh06a4308_0
#   prompt_toolkit                                    3.0.8-0 --> 3.0.17-hd3eb1b0_0
#   psutil                               5.7.2-py38he774522_0 --> 5.8.0-py38h2bbff1b_1
#   py                                             1.9.0-py_0 --> 1.10.0-pyhd3eb1b0_0
#   pydocstyle                                     5.1.1-py_0 --> 6.0.0-pyhd3eb1b0_0
#   pygments                               2.7.2-pyhd3eb1b0_0 --> 2.8.1-pyhd3eb1b0_0
#   pylint                                       2.6.0-py38_0 --> 2.7.4-py38haa95532_1
#   pyopenssl                                     19.1.0-py_1 --> 20.0.1-pyhd3eb1b0_1
#   pytest                                       6.1.1-py38_0 --> 6.2.3-py38haa95532_2
#   python-libarchive~                               2.9-py_0 --> 2.9-pyhd3eb1b0_1
#   pytz                                          2020.1-py_0 --> 2021.1-pyhd3eb1b0_0
#   pyyaml                               5.3.1-py38he774522_1 --> 5.4.1-py38h2bbff1b_1
#   pyzmq                               19.0.2-py38ha925a31_1 --> 20.0.0-py38hd77b12b_1
#   qdarkstyle                                     2.8.1-py_0 --> 3.0.2-pyhd3eb1b0_0
#   qtawesome                                      1.0.1-py_0 --> 1.0.2-pyhd3eb1b0_0
#   qtconsole                                      4.7.7-py_0 --> 5.0.3-pyhd3eb1b0_0
#   regex                           2020.10.15-py38he774522_0 --> 2021.4.4-py38h2bbff1b_0
#   requests                                      2.24.0-py_0 --> 2.25.1-pyhd3eb1b0_0
#   rtree                                0.9.4-py38h21ff451_1 --> 0.9.7-py38h2eaa2aa_1
#   ruamel_yaml                        0.15.87-py38he774522_1 --> 0.15.100-py38h2bbff1b_0
#   scikit-image                        0.17.2-py38h1e1f486_0 --> 0.18.1-py38hf11a4ad_0
#   scikit-learn                        0.23.2-py38h47e9c7a_0 --> 0.24.1-py38hf11a4ad_0
#   scipy                                1.5.2-py38h14eb087_0 --> 1.6.2-py38h14eb087_0
#   seaborn                                       0.11.0-py_0 --> 0.11.1-pyhd3eb1b0_0
#   send2trash         pkgs/main/win-64::send2trash-1.5.0-py~ --> pkgs/main/noarch::send2trash-1.5.0-pyhd3eb1b0_1
#   setuptools                          50.3.1-py38haa95532_1 --> 52.0.0-py38haa95532_0
#   singledispatch                            3.4.0.3-py_1001 --> 3.6.1-pyhd3eb1b0_1001
#   snowballstemmer                                2.0.0-py_0 --> 2.1.0-pyhd3eb1b0_0
#   sortedcollections                              1.2.1-py_0 --> 2.1.0-pyhd3eb1b0_0
#   sortedcontainers                               2.2.2-py_0 --> 2.3.0-pyhd3eb1b0_0
#   soupsieve                                      2.0.1-py_0 --> 2.2.1-pyhd3eb1b0_0
#   sqlalchemy                          1.3.20-py38h2bbff1b_0 --> 1.4.7-py38h2bbff1b_0
#   sqlite                                  3.33.0-h2a8f88b_0 --> 3.35.4-h2bbff1b_0
#   statsmodels                         0.12.0-py38he774522_0 --> 0.12.2-py38h2bbff1b_0
#   sympy                                1.6.2-py38haa95532_1 --> 1.8-py38haa95532_0
#   terminado                                    0.9.1-py38_0 --> 0.9.4-py38haa95532_0
#   tifffile           pkgs/main/win-64::tifffile-2020.10.1-~ --> pkgs/main/noarch::tifffile-2021.3.31-pyhd3eb1b0_1
#   toml                                          0.10.1-py_0 --> 0.10.2-pyhd3eb1b0_0
#   tornado                              6.0.4-py38he774522_1 --> 6.1-py38h2bbff1b_0
#   tqdm                                          4.50.2-py_0 --> 4.59.0-pyhd3eb1b0_1
#   ujson                                4.0.1-py38ha925a31_0 --> 4.0.2-py38hd77b12b_0
#   urllib3                                      1.25.11-py_0 --> 1.26.4-pyhd3eb1b0_0
#   vc                                        14.1-h0510ff6_4 --> 14.2-h21ff451_1
#   vs2015_runtime                     14.16.27012-hf0eaf9b_3 --> 14.27.29016-h5e58377_2
#   watchdog                                    0.10.3-py38_0 --> 1.0.2-py38haa95532_1
#   wheel                                         0.35.1-py_0 --> 0.36.2-pyhd3eb1b0_0
#   wrapt                               1.11.2-py38he774522_0 --> 1.12.1-py38he774522_1
#   xlrd                                           1.2.0-py_0 --> 2.0.1-pyhd3eb1b0_0
#   xlsxwriter                                     1.3.7-py_0 --> 1.3.8-pyhd3eb1b0_0
#   xlwings                                     0.20.8-py38_0 --> 0.23.0-py38haa95532_0
#   yapf                                          0.30.0-py_0 --> 0.31.0-pyhd3eb1b0_0
#   zeromq                                   4.3.2-ha925a31_3 --> 4.3.3-ha925a31_3
#   zipp                                   3.4.0-pyhd3eb1b0_0 --> 3.4.1-pyhd3eb1b0_0
#   zope.interface                       5.1.2-py38he774522_0 --> 5.3.0-py38h2bbff1b_0
#
# The following packages will be DOWNGRADED:
#
#   alabaster                                     0.7.12-py_0 --> 0.7.12-pyhd3eb1b0_0
#   anaconda                                   2020.11-py38_0 --> custom-py38_1
#   argon2-cffi                         20.1.0-py38he774522_1 --> 20.1.0-py38h2bbff1b_1
#   async_generator                                 1.10-py_0 --> 1.10-pyhd3eb1b0_0
#   backcall                                       0.2.0-py_0 --> 0.2.0-pyhd3eb1b0_0
#   backports                                        1.0-py_2 --> 1.0-pyhd3eb1b0_2
#   beautifulsoup4                         4.9.3-pyhb0f4dca_0 --> 4.9.3-pyha847dfd_0
#   click                                          7.1.2-py_0 --> 7.1.2-pyhd3eb1b0_0
#   colorama                                       0.4.4-py_0 --> 0.4.4-pyhd3eb1b0_0
#   decorator                                      4.4.2-py_0 --> 4.4.2-pyhd3eb1b0_0
#   flask                                          1.1.2-py_0 --> 1.1.2-pyhd3eb1b0_0
#   glob2                                            0.7-py_0 --> 0.7-pyhd3eb1b0_0
#   idna                                            2.10-py_0 --> 2.10-pyhd3eb1b0_0
#   imageio                                        2.9.0-py_0 --> 2.9.0-pyhd3eb1b0_0
#   imagesize                                      1.2.0-py_0 --> 1.2.0-pyhd3eb1b0_0
#   iniconfig                                      1.1.1-py_0 --> 1.1.1-pyhd3eb1b0_0
#   itsdangerous                                   1.1.0-py_0 --> 1.1.0-pyhd3eb1b0_0
#   libspatialindex                          1.9.3-h33f27b4_0 --> 1.9.3-h6c2663c_0
#   mkl-service                          2.3.0-py38hb782905_0 --> 2.3.0-py38h196d8e1_0
#   pluggy                                      0.13.1-py38_0 --> 0.13.1-py38haa95532_0
#   pycodestyle                                    2.6.0-py_0 --> 2.6.0-pyhd3eb1b0_0
#   pycosat                              0.6.3-py38he774522_0 --> 0.6.3-py38h2bbff1b_0
#   pyflakes                                       2.2.0-py_0 --> 2.2.0-pyhd3eb1b0_0
#   pyparsing                                      2.4.7-py_0 --> 2.4.7-pyhd3eb1b0_0
#   pysocks                                      1.7.1-py38_0 --> 1.7.1-py38haa95532_0
#   python-dateutil                                2.8.1-py_0 --> 2.8.1-pyhd3eb1b0_0
#   sphinxcontrib-app~                             1.0.2-py_0 --> 1.0.2-pyhd3eb1b0_0
#   sphinxcontrib-dev~                             1.0.2-py_0 --> 1.0.2-pyhd3eb1b0_0
#   sphinxcontrib-htm~                             1.0.3-py_0 --> 1.0.3-pyhd3eb1b0_0
#   sphinxcontrib-jsm~                             1.0.1-py_0 --> 1.0.1-pyhd3eb1b0_0
#   sphinxcontrib-qth~                             1.0.3-py_0 --> 1.0.3-pyhd3eb1b0_0
#   sphinxcontrib-ser~                             1.1.4-py_0 --> 1.1.4-pyhd3eb1b0_0
#   testpath                                       0.4.4-py_0 --> 0.4.4-pyhd3eb1b0_0
#   toolz                                         0.11.1-py_0 --> 0.11.1-pyhd3eb1b0_0
#   traitlets                                      5.0.5-py_0 --> 5.0.5-pyhd3eb1b0_0
#   typing_extensions                            3.7.4.3-py_0 --> 3.7.4.3-pyha847dfd_0
#   werkzeug                                       1.0.1-py_0 --> 1.0.1-pyhd3eb1b0_0
#   win_inet_pton                                1.1.0-py38_0 --> 1.1.0-py38haa95532_0
#   zict                                           2.0.0-py_0 --> 2.0.0-pyhd3eb1b0_0
#
#
#
# Downloading and Extracting Packages
#
# matplotlib-3.3.4     | 27 KB     |            |   0%
# matplotlib-3.3.4     | 27 KB     | #####9     |  60%
# matplotlib-3.3.4     | 27 KB     | ########## | 100%
#
# prompt_toolkit-3.0.1 | 12 KB     |            |   0%
# prompt_toolkit-3.0.1 | 12 KB     | ########## | 100%
# prompt_toolkit-3.0.1 | 12 KB     | ########## | 100%
#
# xlrd-2.0.1           | 90 KB     |            |   0%
# xlrd-2.0.1           | 90 KB     | ########## | 100%
# xlrd-2.0.1           | 90 KB     | ########## | 100%
#
# sortedcontainers-2.3 | 26 KB     |            |   0%
# sortedcontainers-2.3 | 26 KB     | ########## | 100%
# sortedcontainers-2.3 | 26 KB     | ########## | 100%
#
# terminado-0.9.4      | 26 KB     |            |   0%
# terminado-0.9.4      | 26 KB     | ########## | 100%
# terminado-0.9.4      | 26 KB     | ########## | 100%
#
# singledispatch-3.6.1 | 13 KB     |            |   0%
# singledispatch-3.6.1 | 13 KB     | ########## | 100%
# singledispatch-3.6.1 | 13 KB     | ########## | 100%
#
# sqlalchemy-1.4.7     | 1.8 MB    |            |   0%
# sqlalchemy-1.4.7     | 1.8 MB    | #8         |  18%
# sqlalchemy-1.4.7     | 1.8 MB    | ########## | 100%
# sqlalchemy-1.4.7     | 1.8 MB    | ########## | 100%
#
# ipython_genutils-0.2 | 27 KB     |            |   0%
# ipython_genutils-0.2 | 27 KB     | ########## | 100%
# ipython_genutils-0.2 | 27 KB     | ########## | 100%
#
# xlwings-0.23.0       | 859 KB    |            |   0%
# xlwings-0.23.0       | 859 KB    | ########## | 100%
# xlwings-0.23.0       | 859 KB    | ########## | 100%
#
# py-1.10.0            | 76 KB     |            |   0%
# py-1.10.0            | 76 KB     | ########## | 100%
# py-1.10.0            | 76 KB     | ########## | 100%
#
# libdeflate-1.7       | 49 KB     |            |   0%
# libdeflate-1.7       | 49 KB     | ########## | 100%
#
# nbclassic-0.2.6      | 19 KB     |            |   0%
# nbclassic-0.2.6      | 19 KB     | ########## | 100%
# nbclassic-0.2.6      | 19 KB     | ########## | 100%
#
# cffi-1.14.5          | 224 KB    |            |   0%
# cffi-1.14.5          | 224 KB    | ########## | 100%
# cffi-1.14.5          | 224 KB    | ########## | 100%
#
# libspatialindex-1.9. | 351 KB    |            |   0%
# libspatialindex-1.9. | 351 KB    | ########## | 100%
# libspatialindex-1.9. | 351 KB    | ########## | 100%
#
# astropy-4.2.1        | 5.9 MB    |            |   0%
# astropy-4.2.1        | 5.9 MB    | #7         |  17%
# astropy-4.2.1        | 5.9 MB    | #########3 |  94%
# astropy-4.2.1        | 5.9 MB    | ########## | 100%
#
# pyparsing-2.4.7      | 59 KB     |            |   0%
# pyparsing-2.4.7      | 59 KB     | ########## | 100%
#
# anyio-2.2.0          | 126 KB    |            |   0%
# anyio-2.2.0          | 126 KB    | ########## | 100%
# anyio-2.2.0          | 126 KB    | ########## | 100%
#
# yapf-0.31.0          | 126 KB    |            |   0%
# yapf-0.31.0          | 126 KB    | ########## | 100%
# yapf-0.31.0          | 126 KB    | ########## | 100%
#
# iniconfig-1.1.1      | 8 KB      |            |   0%
# iniconfig-1.1.1      | 8 KB      | ########## | 100%
#
# openssl-1.1.1k       | 4.8 MB    |            |   0%
# openssl-1.1.1k       | 4.8 MB    | ####1      |  41%
# openssl-1.1.1k       | 4.8 MB    | ########## | 100%
# openssl-1.1.1k       | 4.8 MB    | ########## | 100%
#
# tifffile-2021.3.31   | 132 KB    |            |   0%
# tifffile-2021.3.31   | 132 KB    | ########## | 100%
# tifffile-2021.3.31   | 132 KB    | ########## | 100%
#
# brotlipy-0.7.0       | 412 KB    |            |   0%
# brotlipy-0.7.0       | 412 KB    | ########## | 100%
# brotlipy-0.7.0       | 412 KB    | ########## | 100%
#
# importlib-metadata-3 | 34 KB     |            |   0%
# importlib-metadata-3 | 34 KB     | ########## | 100%
#
# pyerfa-1.7.2         | 301 KB    |            |   0%
# pyerfa-1.7.2         | 301 KB    | ########## | 100%
# pyerfa-1.7.2         | 301 KB    | ########## | 100%
#
# backports.shutil_get | 10 KB     |            |   0%
# backports.shutil_get | 10 KB     | ########## | 100%
#
# defusedxml-0.7.1     | 23 KB     |            |   0%
# defusedxml-0.7.1     | 23 KB     | ########## | 100%
# defusedxml-0.7.1     | 23 KB     | ########## | 100%
#
# comtypes-1.1.9       | 237 KB    |            |   0%
# comtypes-1.1.9       | 237 KB    | ########## | 100%
# comtypes-1.1.9       | 237 KB    | ########## | 100%
#
# send2trash-1.5.0     | 14 KB     |            |   0%
# send2trash-1.5.0     | 14 KB     | ########## | 100%
# send2trash-1.5.0     | 14 KB     | ########## | 100%
#
# ipywidgets-7.6.3     | 105 KB    |            |   0%
# ipywidgets-7.6.3     | 105 KB    | ########## | 100%
# ipywidgets-7.6.3     | 105 KB    | ########## | 100%
#
# filelock-3.0.12      | 10 KB     |            |   0%
# filelock-3.0.12      | 10 KB     | ########## | 100%
#
# python-libarchive-c- | 47 KB     |            |   0%
# python-libarchive-c- | 47 KB     | ########## | 100%
# python-libarchive-c- | 47 KB     | ########## | 100%
#
# decorator-4.4.2      | 12 KB     |            |   0%
# decorator-4.4.2      | 12 KB     | ########## | 100%
#
# jupyter_console-6.4. | 23 KB     |            |   0%
# jupyter_console-6.4. | 23 KB     | ########## | 100%
# jupyter_console-6.4. | 23 KB     | ########## | 100%
#
# pyzmq-20.0.0         | 405 KB    |            |   0%
# pyzmq-20.0.0         | 405 KB    | ########## | 100%
# pyzmq-20.0.0         | 405 KB    | ########## | 100%
#
# regex-2021.4.4       | 302 KB    |            |   0%
# regex-2021.4.4       | 302 KB    | ########## | 100%
# regex-2021.4.4       | 302 KB    | ########## | 100%
#
# lz4-c-1.9.3          | 131 KB    |            |   0%
# lz4-c-1.9.3          | 131 KB    | ########## | 100%
#
# imagecodecs-2021.3.3 | 6.1 MB    |            |   0%
# imagecodecs-2021.3.3 | 6.1 MB    | ####6      |  46%
# imagecodecs-2021.3.3 | 6.1 MB    | ########## | 100%
# imagecodecs-2021.3.3 | 6.1 MB    | ########## | 100%
#
# matplotlib-base-3.3. | 5.1 MB    |            |   0%
# matplotlib-base-3.3. | 5.1 MB    | ##2        |  23%
# matplotlib-base-3.3. | 5.1 MB    | ########## | 100%
# matplotlib-base-3.3. | 5.1 MB    | ########## | 100%
#
# tqdm-4.59.0          | 93 KB     |            |   0%
# tqdm-4.59.0          | 93 KB     | #7         |  17%
# tqdm-4.59.0          | 93 KB     | ########## | 100%
# tqdm-4.59.0          | 93 KB     | ########## | 100%
#
# pkginfo-1.7.0        | 60 KB     |            |   0%
# pkginfo-1.7.0        | 60 KB     | ########## | 100%
# pkginfo-1.7.0        | 60 KB     | ########## | 100%
#
# zipp-3.4.1           | 15 KB     |            |   0%
# zipp-3.4.1           | 15 KB     | ########## | 100%
#
# notebook-6.3.0       | 4.4 MB    |            |   0%
# notebook-6.3.0       | 4.4 MB    | ########   |  80%
# notebook-6.3.0       | 4.4 MB    | ########## | 100%
#
# pyopenssl-20.0.1     | 49 KB     |            |   0%
# pyopenssl-20.0.1     | 49 KB     | ########## | 100%
# pyopenssl-20.0.1     | 49 KB     | ########## | 100%
#
# jupyterlab_widgets-1 | 109 KB    |            |   0%
# jupyterlab_widgets-1 | 109 KB    | ########## | 100%
# jupyterlab_widgets-1 | 109 KB    | ########## | 100%
#
# sphinxcontrib-qthelp | 26 KB     |            |   0%
# sphinxcontrib-qthelp | 26 KB     | ########## | 100%
# sphinxcontrib-qthelp | 26 KB     | ########## | 100%
#
# fsspec-0.9.0         | 83 KB     |            |   0%
# fsspec-0.9.0         | 83 KB     | ########## | 100%
# fsspec-0.9.0         | 83 KB     | ########## | 100%
#
# sphinxcontrib-appleh | 29 KB     |            |   0%
# sphinxcontrib-appleh | 29 KB     | ########## | 100%
# sphinxcontrib-appleh | 29 KB     | ########## | 100%
#
# partd-1.2.0          | 19 KB     |            |   0%
# partd-1.2.0          | 19 KB     | ########## | 100%
# partd-1.2.0          | 19 KB     | ########## | 100%
#
# keyring-22.3.0       | 71 KB     |            |   0%
# keyring-22.3.0       | 71 KB     | ########## | 100%
# keyring-22.3.0       | 71 KB     | ########## | 100%
#
# psutil-5.8.0         | 350 KB    |            |   0%
# psutil-5.8.0         | 350 KB    | ########## | 100%
# psutil-5.8.0         | 350 KB    | ########## | 100%
#
# pytest-6.2.3         | 440 KB    |            |   0%
# pytest-6.2.3         | 440 KB    | ########## | 100%
# pytest-6.2.3         | 440 KB    | ########## | 100%
#
# toolz-0.11.1         | 46 KB     |            |   0%
# toolz-0.11.1         | 46 KB     | ########## | 100%
# toolz-0.11.1         | 46 KB     | ########## | 100%
#
# ruamel_yaml-0.15.100 | 273 KB    |            |   0%
# ruamel_yaml-0.15.100 | 273 KB    | ########## | 100%
# ruamel_yaml-0.15.100 | 273 KB    | ########## | 100%
#
# itsdangerous-1.1.0   | 17 KB     |            |   0%
# itsdangerous-1.1.0   | 17 KB     | ########## | 100%
#
# pexpect-4.8.0        | 53 KB     |            |   0%
# pexpect-4.8.0        | 53 KB     | ########## | 100%
# pexpect-4.8.0        | 53 KB     | ########## | 100%
#
# pytz-2021.1          | 181 KB    |            |   0%
# pytz-2021.1          | 181 KB    | ########## | 100%
# pytz-2021.1          | 181 KB    | ########## | 100%
#
# imagesize-1.2.0      | 8 KB      |            |   0%
# imagesize-1.2.0      | 8 KB      | ########## | 100%
# imagesize-1.2.0      | 8 KB      | ########## | 100%
#
# snowballstemmer-2.1. | 62 KB     |            |   0%
# snowballstemmer-2.1. | 62 KB     | ########## | 100%
# snowballstemmer-2.1. | 62 KB     | ########## | 100%
#
# importlib_metadata-3 | 11 KB     |            |   0%
# importlib_metadata-3 | 11 KB     | ########## | 100%
#
# pip-21.0.1           | 1.8 MB    |            |   0%
# pip-21.0.1           | 1.8 MB    | ########## | 100%
# pip-21.0.1           | 1.8 MB    | ########## | 100%
#
# python-dateutil-2.8. | 221 KB    |            |   0%
# python-dateutil-2.8. | 221 KB    | ########## | 100%
# python-dateutil-2.8. | 221 KB    | ########## | 100%
#
# qtawesome-1.0.2      | 760 KB    |            |   0%
# qtawesome-1.0.2      | 760 KB    | ########## | 100%
# qtawesome-1.0.2      | 760 KB    | ########## | 100%
#
# brotli-1.0.9         | 332 KB    |            |   0%
# brotli-1.0.9         | 332 KB    | ########## | 100%
# brotli-1.0.9         | 332 KB    | ########## | 100%
#
# toml-0.10.2          | 20 KB     |            |   0%
# toml-0.10.2          | 20 KB     | ########## | 100%
# toml-0.10.2          | 20 KB     | ########## | 100%
#
# pycosat-0.6.3        | 75 KB     |            |   0%
# pycosat-0.6.3        | 75 KB     | ########## | 100%
#
# ptyprocess-0.7.0     | 17 KB     |            |   0%
# ptyprocess-0.7.0     | 17 KB     | ########## | 100%
#
# statsmodels-0.12.2   | 8.2 MB    |            |   0%
# statsmodels-0.12.2   | 8.2 MB    | ####1      |  41%
# statsmodels-0.12.2   | 8.2 MB    | ########## | 100%
# statsmodels-0.12.2   | 8.2 MB    | ########## | 100%
#
# sphinxcontrib-serial | 24 KB     |            |   0%
# sphinxcontrib-serial | 24 KB     | ########## | 100%
# sphinxcontrib-serial | 24 KB     | ########## | 100%
#
# networkx-2.5.1       | 1.1 MB    |            |   0%
# networkx-2.5.1       | 1.1 MB    | ########## | 100%
# networkx-2.5.1       | 1.1 MB    | ########## | 100%
#
# jupyter_core-4.7.1   | 85 KB     |            |   0%
# jupyter_core-4.7.1   | 85 KB     | ########## | 100%
# jupyter_core-4.7.1   | 85 KB     | ########## | 100%
#
# docutils-0.17        | 695 KB    |            |   0%
# docutils-0.17        | 695 KB    | ########## | 100%
# docutils-0.17        | 695 KB    | ########## | 100%
#
# lxml-4.6.3           | 979 KB    |            |   0%
# lxml-4.6.3           | 979 KB    | ########## | 100%
# lxml-4.6.3           | 979 KB    | ########## | 100%
#
# nltk-3.6.1           | 988 KB    |            |   0%
# nltk-3.6.1           | 988 KB    | ########## | 100%
# nltk-3.6.1           | 988 KB    | ########## | 100%
#
# certifi-2020.12.5    | 141 KB    |            |   0%
# certifi-2020.12.5    | 141 KB    | ########## | 100%
#
# jupyter_server-1.4.1 | 332 KB    |            |   0%
# jupyter_server-1.4.1 | 332 KB    | ########## | 100%
# jupyter_server-1.4.1 | 332 KB    | ########## | 100%
#
# glob2-0.7            | 12 KB     |            |   0%
# glob2-0.7            | 12 KB     | ########## | 100%
#
# colorama-0.4.4       | 21 KB     |            |   0%
# colorama-0.4.4       | 21 KB     | ########## | 100%
# colorama-0.4.4       | 21 KB     | ########## | 100%
#
# idna-2.10            | 52 KB     |            |   0%
# idna-2.10            | 52 KB     | ########## | 100%
# idna-2.10            | 52 KB     | ########## | 100%
#
# mock-4.0.3           | 29 KB     |            |   0%
# mock-4.0.3           | 29 KB     | ########## | 100%
# mock-4.0.3           | 29 KB     | ########## | 100%
#
# sphinxcontrib-jsmath | 8 KB      |            |   0%
# sphinxcontrib-jsmath | 8 KB      | ########## | 100%
#
# kiwisolver-1.3.1     | 52 KB     |            |   0%
# kiwisolver-1.3.1     | 52 KB     | ########## | 100%
#
# chardet-4.0.0        | 211 KB    |            |   0%
# chardet-4.0.0        | 211 KB    | ########## | 100%
# chardet-4.0.0        | 211 KB    | ########## | 100%
#
# blosc-1.21.0         | 139 KB    |            |   0%
# blosc-1.21.0         | 139 KB    | ########## | 100%
#
# pyyaml-5.4.1         | 151 KB    |            |   0%
# pyyaml-5.4.1         | 151 KB    | ########## | 100%
# pyyaml-5.4.1         | 151 KB    | ########## | 100%
#
# flask-1.1.2          | 70 KB     |            |   0%
# flask-1.1.2          | 70 KB     | ########## | 100%
#
# ujson-4.0.2          | 46 KB     |            |   0%
# ujson-4.0.2          | 46 KB     | ########## | 100%
#
# more-itertools-8.7.0 | 42 KB     |            |   0%
# more-itertools-8.7.0 | 42 KB     | ########## | 100%
# more-itertools-8.7.0 | 42 KB     | ########## | 100%
#
# sortedcollections-2. | 12 KB     |            |   0%
# sortedcollections-2. | 12 KB     | ########## | 100%
# sortedcollections-2. | 12 KB     | ########## | 100%
#
# jupyterlab-3.0.11    | 3.5 MB    |            |   0%
# jupyterlab-3.0.11    | 3.5 MB    | ########## | 100%
# jupyterlab-3.0.11    | 3.5 MB    | ########## | 100%
#
# nbformat-5.1.3       | 44 KB     |            |   0%
# nbformat-5.1.3       | 44 KB     | ########## | 100%
# nbformat-5.1.3       | 44 KB     | ########## | 100%
#
# scikit-image-0.18.1  | 9.1 MB    |            |   0%
# scikit-image-0.18.1  | 9.1 MB    | ####1      |  42%
# scikit-image-0.18.1  | 9.1 MB    | ########## | 100%
# scikit-image-0.18.1  | 9.1 MB    | ########## | 100%
#
# typing_extensions-3. | 25 KB     |            |   0%
# typing_extensions-3. | 25 KB     | ########## | 100%
#
# requests-2.25.1      | 52 KB     |            |   0%
# requests-2.25.1      | 52 KB     | ########## | 100%
# requests-2.25.1      | 52 KB     | ########## | 100%
#
# mpir-3.0.0           | 1.3 MB    |            |   0%
# mpir-3.0.0           | 1.3 MB    | ########## | 100%
# mpir-3.0.0           | 1.3 MB    | ########## | 100%
#
# path-15.1.2          | 38 KB     |            |   0%
# path-15.1.2          | 38 KB     | ########## | 100%
#
# distributed-2021.4.0 | 1.0 MB    |            |   0%
# distributed-2021.4.0 | 1.0 MB    | ########## | 100%
# distributed-2021.4.0 | 1.0 MB    | ########## | 100%
#
# jupyter_client-6.1.1 | 88 KB     |            |   0%
# jupyter_client-6.1.1 | 88 KB     | ########## | 100%
# jupyter_client-6.1.1 | 88 KB     | ########## | 100%
#
# werkzeug-1.0.1       | 239 KB    |            |   0%
# werkzeug-1.0.1       | 239 KB    | ########## | 100%
# werkzeug-1.0.1       | 239 KB    | ########## | 100%
#
# seaborn-0.11.1       | 212 KB    |            |   0%
# seaborn-0.11.1       | 212 KB    | ########## | 100%
# seaborn-0.11.1       | 212 KB    | ########## | 100%
#
# watchdog-1.0.2       | 104 KB    |            |   0%
# watchdog-1.0.2       | 104 KB    | ########## | 100%
# watchdog-1.0.2       | 104 KB    | ########## | 100%
#
# isort-5.8.0          | 81 KB     |            |   0%
# isort-5.8.0          | 81 KB     | ########## | 100%
# isort-5.8.0          | 81 KB     | ########## | 100%
#
# openjpeg-2.3.0       | 205 KB    |            |   0%
# openjpeg-2.3.0       | 205 KB    | ########## | 100%
# openjpeg-2.3.0       | 205 KB    | ########## | 100%
#
# sphinxcontrib-devhel | 23 KB     |            |   0%
# sphinxcontrib-devhel | 23 KB     | ########## | 100%
# sphinxcontrib-devhel | 23 KB     | ########## | 100%
#
# libtiff-4.2.0        | 786 KB    |            |   0%
# libtiff-4.2.0        | 786 KB    | ########## | 100%
# libtiff-4.2.0        | 786 KB    | ########## | 100%
#
# mpc-1.1.0            | 260 KB    |            |   0%
# mpc-1.1.0            | 260 KB    | ########## | 100%
# mpc-1.1.0            | 260 KB    | ########## | 100%
#
# babel-2.9.0          | 5.5 MB    |            |   0%
# babel-2.9.0          | 5.5 MB    | #########9 | 100%
# babel-2.9.0          | 5.5 MB    | ########## | 100%
#
# libzopfli-1.0.3      | 176 KB    |            |   0%
# libzopfli-1.0.3      | 176 KB    | ########## | 100%
# libzopfli-1.0.3      | 176 KB    | ########## | 100%
#
# giflib-5.2.1         | 81 KB     |            |   0%
# giflib-5.2.1         | 81 KB     | ########## | 100%
# giflib-5.2.1         | 81 KB     | ########## | 100%
#
# libaec-1.0.4         | 31 KB     |            |   0%
# libaec-1.0.4         | 31 KB     | ########## | 100%
#
# sqlite-3.35.4        | 761 KB    |            |   0%
# sqlite-3.35.4        | 761 KB    | ########## | 100%
# sqlite-3.35.4        | 761 KB    | ########## | 100%
#
# bitarray-1.9.2       | 118 KB    |            |   0%
# bitarray-1.9.2       | 118 KB    | ########## | 100%
#
# traitlets-5.0.5      | 81 KB     |            |   0%
# traitlets-5.0.5      | 81 KB     | ########## | 100%
# traitlets-5.0.5      | 81 KB     | ########## | 100%
#
# soupsieve-2.2.1      | 32 KB     |            |   0%
# soupsieve-2.2.1      | 32 KB     | ########## | 100%
#
# mkl_fft-1.3.0        | 134 KB    |            |   0%
# mkl_fft-1.3.0        | 134 KB    | ########## | 100%
# mkl_fft-1.3.0        | 134 KB    | ########## | 100%
#
# numexpr-2.7.3        | 125 KB    |            |   0%
# numexpr-2.7.3        | 125 KB    | ########## | 100%
# numexpr-2.7.3        | 125 KB    | ########## | 100%
#
# wheel-0.36.2         | 33 KB     |            |   0%
# wheel-0.36.2         | 33 KB     | ########## | 100%
# wheel-0.36.2         | 33 KB     | ########## | 100%
#
# urllib3-1.26.4       | 105 KB    |            |   0%
# urllib3-1.26.4       | 105 KB    | ########## | 100%
# urllib3-1.26.4       | 105 KB    | ########## | 100%
#
# autopep8-1.5.6       | 43 KB     |            |   0%
# autopep8-1.5.6       | 43 KB     | ########## | 100%
#
# anaconda-custom      | 36 KB     |            |   0%
# anaconda-custom      | 36 KB     | ########## | 100%
#
# lcms2-2.12           | 454 KB    |            |   0%
# lcms2-2.12           | 454 KB    | ########## | 100%
# lcms2-2.12           | 454 KB    | ########## | 100%
#
# click-7.1.2          | 64 KB     |            |   0%
# click-7.1.2          | 64 KB     | ########## | 100%
#
# prompt-toolkit-3.0.1 | 256 KB    |            |   0%
# prompt-toolkit-3.0.1 | 256 KB    | ########## | 100%
# prompt-toolkit-3.0.1 | 256 KB    | ########## | 100%
#
# scipy-1.6.2          | 13.0 MB   |            |   0%
# scipy-1.6.2          | 13.0 MB   | ###2       |  33%
# scipy-1.6.2          | 13.0 MB   | ########## | 100%
# scipy-1.6.2          | 13.0 MB   | ########## | 100%
#
# ipython-7.22.0       | 998 KB    |            |   0%
# ipython-7.22.0       | 998 KB    | ########## | 100%
# ipython-7.22.0       | 998 KB    | ########## | 100%
#
# flake8-3.9.0         | 129 KB    |            |   0%
# flake8-3.9.0         | 129 KB    | ########## | 100%
# flake8-3.9.0         | 129 KB    | ########## | 100%
#
# joblib-1.0.1         | 208 KB    |            |   0%
# joblib-1.0.1         | 208 KB    | ########## | 100%
# joblib-1.0.1         | 208 KB    | ########## | 100%
#
# backports-1.0        | 210 KB    |            |   0%
# backports-1.0        | 210 KB    | ########## | 100%
# backports-1.0        | 210 KB    | ########## | 100%
#
# beautifulsoup4-4.9.3 | 86 KB     |            |   0%
# beautifulsoup4-4.9.3 | 86 KB     | ########## | 100%
#
# win_inet_pton-1.1.0  | 35 KB     |            |   0%
# win_inet_pton-1.1.0  | 35 KB     | ########## | 100%
# win_inet_pton-1.1.0  | 35 KB     | ########## | 100%
#
# jupyterlab_server-2. | 37 KB     |            |   0%
# jupyterlab_server-2. | 37 KB     | ########## | 100%
# jupyterlab_server-2. | 37 KB     | ########## | 100%
#
# pathlib2-2.3.5       | 62 KB     |            |   0%
# pathlib2-2.3.5       | 62 KB     | ########## | 100%
# pathlib2-2.3.5       | 62 KB     | ########## | 100%
#
# lerc-2.2.1           | 114 KB    |            |   0%
# lerc-2.2.1           | 114 KB    | ########## | 100%
# lerc-2.2.1           | 114 KB    | ########## | 100%
#
# pysocks-1.7.1        | 31 KB     |            |   0%
# pysocks-1.7.1        | 31 KB     | ########## | 100%
#
# pluggy-0.13.1        | 34 KB     |            |   0%
# pluggy-0.13.1        | 34 KB     | ########## | 100%
# pluggy-0.13.1        | 34 KB     | ########## | 100%
#
# prometheus_client-0. | 46 KB     |            |   0%
# prometheus_client-0. | 46 KB     | ########## | 100%
#
# bleach-3.3.0         | 113 KB    |            |   0%
# bleach-3.3.0         | 113 KB    | ########## | 100%
# bleach-3.3.0         | 113 KB    | ########## | 100%
#
# zict-2.0.0           | 10 KB     |            |   0%
# zict-2.0.0           | 10 KB     | ########## | 100%
# zict-2.0.0           | 10 KB     | ########## | 100%
#
# msgpack-python-1.0.2 | 76 KB     |            |   0%
# msgpack-python-1.0.2 | 76 KB     | ########## | 100%
#
# pandoc-2.12          | 13.2 MB   |            |   0%
# pandoc-2.12          | 13.2 MB   | ##9        |  30%
# pandoc-2.12          | 13.2 MB   | ########## | 100%
# pandoc-2.12          | 13.2 MB   | ########## | 100%
#
# zfp-0.5.5            | 139 KB    |            |   0%
# zfp-0.5.5            | 139 KB    | ########## | 100%
# zfp-0.5.5            | 139 KB    | ########## | 100%
#
# ca-certificates-2021 | 115 KB    |            |   0%
# ca-certificates-2021 | 115 KB    | ########## | 100%
#
# zeromq-4.3.3         | 4.2 MB    |            |   0%
# zeromq-4.3.3         | 4.2 MB    | ########## | 100%
# zeromq-4.3.3         | 4.2 MB    | ########## | 100%
#
# jinja2-2.11.3        | 101 KB    |            |   0%
# jinja2-2.11.3        | 101 KB    | ########## | 100%
# jinja2-2.11.3        | 101 KB    | ########## | 100%
#
# jupyter-packaging-0. | 14 KB     |            |   0%
# jupyter-packaging-0. | 14 KB     | ########## | 100%
#
# vs2015_runtime-14.27 | 1007 KB   |            |   0%
# vs2015_runtime-14.27 | 1007 KB   | ########## | 100%
# vs2015_runtime-14.27 | 1007 KB   | ########## | 100%
#
# llvmlite-0.36.0      | 12.4 MB   |            |   0%
# llvmlite-0.36.0      | 12.4 MB   | ###2       |  33%
# llvmlite-0.36.0      | 12.4 MB   | ########## | 100%
# llvmlite-0.36.0      | 12.4 MB   | ########## | 100%
#
# zope.interface-5.3.0 | 300 KB    |            |   0%
# zope.interface-5.3.0 | 300 KB    | ########## | 100%
# zope.interface-5.3.0 | 300 KB    | ########## | 100%
#
# dask-2021.4.0        | 5 KB      |            |   0%
# dask-2021.4.0        | 5 KB      | ########## | 100%
# dask-2021.4.0        | 5 KB      | ########## | 100%
#
# snappy-1.1.8         | 80 KB     |            |   0%
# snappy-1.1.8         | 80 KB     | ########## | 100%
# snappy-1.1.8         | 80 KB     | ########## | 100%
#
# greenlet-1.0.0       | 82 KB     |            |   0%
# greenlet-1.0.0       | 82 KB     | ########## | 100%
# greenlet-1.0.0       | 82 KB     | ########## | 100%
#
# mpmath-1.2.1         | 767 KB    |            |   0%
# mpmath-1.2.1         | 767 KB    | ########## | 100%
# mpmath-1.2.1         | 767 KB    | ########## | 100%
#
# pandas-1.2.4         | 7.9 MB    |            |   0%
# pandas-1.2.4         | 7.9 MB    | ######2    |  62%
# pandas-1.2.4         | 7.9 MB    | ########## | 100%
# pandas-1.2.4         | 7.9 MB    | ########## | 100%
#
# charls-2.2.0         | 82 KB     |            |   0%
# charls-2.2.0         | 82 KB     | ########## | 100%
#
# mpfr-4.0.2           | 1.5 MB    |            |   0%
# mpfr-4.0.2           | 1.5 MB    | ########## | 100%
# mpfr-4.0.2           | 1.5 MB    | ########## | 100%
#
# wrapt-1.12.1         | 49 KB     |            |   0%
# wrapt-1.12.1         | 49 KB     | ########## | 100%
# wrapt-1.12.1         | 49 KB     | ########## | 100%
#
# packaging-20.9       | 37 KB     |            |   0%
# packaging-20.9       | 37 KB     | ########## | 100%
# packaging-20.9       | 37 KB     | ########## | 100%
#
# alabaster-0.7.12     | 16 KB     |            |   0%
# alabaster-0.7.12     | 16 KB     | ########## | 100%
# alabaster-0.7.12     | 16 KB     | ########## | 100%
#
# scikit-learn-0.24.1  | 4.8 MB    |            |   0%
# scikit-learn-0.24.1  | 4.8 MB    | ########7  |  87%
# scikit-learn-0.24.1  | 4.8 MB    | ########## | 100%
#
# gevent-21.1.2        | 1.4 MB    |            |   0%
# gevent-21.1.2        | 1.4 MB    | ########## | 100%
# gevent-21.1.2        | 1.4 MB    | ########## | 100%
#
# pycodestyle-2.6.0    | 38 KB     |            |   0%
# pycodestyle-2.6.0    | 38 KB     | ########## | 100%
#
# bokeh-2.3.1          | 5.9 MB    |            |   0%
# bokeh-2.3.1          | 5.9 MB    | #######4   |  75%
# bokeh-2.3.1          | 5.9 MB    | ########## | 100%
# bokeh-2.3.1          | 5.9 MB    | ########## | 100%
#
# locket-0.2.1         | 10 KB     |            |   0%
# locket-0.2.1         | 10 KB     | ########## | 100%
#
# astroid-2.5          | 281 KB    |            |   0%
# astroid-2.5          | 281 KB    | ########## | 100%
# astroid-2.5          | 281 KB    | ########## | 100%
#
# pickleshare-0.7.5    | 13 KB     |            |   0%
# pickleshare-0.7.5    | 13 KB     | ########## | 100%
# pickleshare-0.7.5    | 13 KB     | ########## | 100%
#
# tbb-2020.3           | 156 KB    |            |   0%
# tbb-2020.3           | 156 KB    | ########## | 100%
# tbb-2020.3           | 156 KB    | ########## | 100%
#
# async_generator-1.10 | 23 KB     |            |   0%
# async_generator-1.10 | 23 KB     | ########## | 100%
# async_generator-1.10 | 23 KB     | ########## | 100%
#
# libllvm9-9.0.1       | 61 KB     |            |   0%
# libllvm9-9.0.1       | 61 KB     | ########## | 100%
# libllvm9-9.0.1       | 61 KB     | ########## | 100%
#
# imageio-2.9.0        | 3.0 MB    |            |   0%
# imageio-2.9.0        | 3.0 MB    | ########## | 100%
# imageio-2.9.0        | 3.0 MB    | ########## | 100%
#
# openpyxl-3.0.7       | 159 KB    |            |   0%
# openpyxl-3.0.7       | 159 KB    | ########## | 100%
# openpyxl-3.0.7       | 159 KB    | ########## | 100%
#
# dask-core-2021.4.0   | 670 KB    |            |   0%
# dask-core-2021.4.0   | 670 KB    | ########## | 100%
# dask-core-2021.4.0   | 670 KB    | ########## | 100%
#
# pillow-8.2.0         | 671 KB    |            |   0%
# pillow-8.2.0         | 671 KB    | ########## | 100%
# pillow-8.2.0         | 671 KB    | ########## | 100%
#
# xlsxwriter-1.3.8     | 109 KB    |            |   0%
# xlsxwriter-1.3.8     | 109 KB    | ########## | 100%
# xlsxwriter-1.3.8     | 109 KB    | ########## | 100%
#
# nose-1.3.7           | 128 KB    |            |   0%
# nose-1.3.7           | 128 KB    | ########## | 100%
# nose-1.3.7           | 128 KB    | ########## | 100%
#
# pyflakes-2.2.0       | 56 KB     |            |   0%
# pyflakes-2.2.0       | 56 KB     | ########## | 100%
# pyflakes-2.2.0       | 56 KB     | ########## | 100%
#
# qdarkstyle-3.0.2     | 337 KB    |            |   0%
# qdarkstyle-3.0.2     | 337 KB    | ########## | 100%
# qdarkstyle-3.0.2     | 337 KB    | ########## | 100%
#
# setuptools-52.0.0    | 726 KB    |            |   0%
# setuptools-52.0.0    | 726 KB    | ########## | 100%
# setuptools-52.0.0    | 726 KB    | ########## | 100%
#
# sympy-1.8            | 9.1 MB    |            |   0%
# sympy-1.8            | 9.1 MB    | ####2      |  43%
# sympy-1.8            | 9.1 MB    | ########## | 100%
# sympy-1.8            | 9.1 MB    | ########## | 100%
#
# mkl-service-2.3.0    | 47 KB     |            |   0%
# mkl-service-2.3.0    | 47 KB     | ########## | 100%
# mkl-service-2.3.0    | 47 KB     | ########## | 100%
#
# pygments-2.8.1       | 703 KB    |            |   0%
# pygments-2.8.1       | 703 KB    | ########## | 100%
# pygments-2.8.1       | 703 KB    | ########## | 100%
#
# sphinxcontrib-htmlhe | 28 KB     |            |   0%
# sphinxcontrib-htmlhe | 28 KB     | ########## | 100%
# sphinxcontrib-htmlhe | 28 KB     | ########## | 100%
#
# argon2-cffi-20.1.0   | 49 KB     |            |   0%
# argon2-cffi-20.1.0   | 49 KB     | ########## | 100%
# argon2-cffi-20.1.0   | 49 KB     | ########## | 100%
#
# lazy-object-proxy-1. | 31 KB     |            |   0%
# lazy-object-proxy-1. | 31 KB     | ########## | 100%
# lazy-object-proxy-1. | 31 KB     | ########## | 100%
#
# backcall-0.2.0       | 13 KB     |            |   0%
# backcall-0.2.0       | 13 KB     | ########## | 100%
#
# rtree-0.9.7          | 49 KB     |            |   0%
# rtree-0.9.7          | 49 KB     | ########## | 100%
# rtree-0.9.7          | 49 KB     | ########## | 100%
#
# numba-0.53.1         | 3.3 MB    |            |   0%
# numba-0.53.1         | 3.3 MB    | ########## | 100%
# numba-0.53.1         | 3.3 MB    | ########## | 100%
#
# sniffio-1.2.0        | 15 KB     |            |   0%
# sniffio-1.2.0        | 15 KB     | ########## | 100%
# sniffio-1.2.0        | 15 KB     | ########## | 100%
#
# testpath-0.4.4       | 85 KB     |            |   0%
# testpath-0.4.4       | 85 KB     | ########## | 100%
#
# qtconsole-5.0.3      | 97 KB     |            |   0%
# qtconsole-5.0.3      | 97 KB     | ########## | 100%
# qtconsole-5.0.3      | 97 KB     | ########## | 100%
#
# anaconda-project-0.9 | 215 KB    |            |   0%
# anaconda-project-0.9 | 215 KB    | ########## | 100%
# anaconda-project-0.9 | 215 KB    | ########## | 100%
#
# _anaconda_depends-20 | 6 KB      |            |   0%
# _anaconda_depends-20 | 6 KB      | ########## | 100%
#
# gmpy2-2.0.8          | 145 KB    |            |   0%
# gmpy2-2.0.8          | 145 KB    | ########## | 100%
# gmpy2-2.0.8          | 145 KB    | ########## | 100%
#
# pylint-2.7.4         | 475 KB    |            |   0%
# pylint-2.7.4         | 475 KB    | ########## | 100%
# pylint-2.7.4         | 475 KB    | ########## | 100%
#
# tornado-6.1          | 612 KB    |            |   0%
# tornado-6.1          | 612 KB    | ########## | 100%
# tornado-6.1          | 612 KB    | ########## | 100%
#
# pydocstyle-6.0.0     | 35 KB     |            |   0%
# pydocstyle-6.0.0     | 35 KB     | ########## | 100%
# pydocstyle-6.0.0     | 35 KB     | ########## | 100%
#
# cython-0.29.23       | 1.7 MB    |            |   0%
# cython-0.29.23       | 1.7 MB    | ########## | 100%
# cython-0.29.23       | 1.7 MB    | ########## | 100%
#
# vc-14.2              | 8 KB      |            |   0%
# vc-14.2              | 8 KB      | ########## | 100%
#
# cryptography-3.4.7   | 643 KB    |            |   0%
# cryptography-3.4.7   | 643 KB    | ########## | 100%
# cryptography-3.4.7   | 643 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting package metadata (current_repodata.json): ...working... done
# Note: you may need to restart the kernel to use updated packages.
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3
#
#   added / updated specs:
#     - python
#
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     nbclient-0.5.3             |     pyhd3eb1b0_0          62 KB
#     nest-asyncio-1.5.1         |     pyhd3eb1b0_0          10 KB
#     python-3.8.8               |       hdbf39b2_5        15.8 MB
#     ------------------------------------------------------------
#                                            Total:        15.9 MB
#
# The following packages will be UPDATED:
#
#   nbclient                                       0.5.1-py_0 --> 0.5.3-pyhd3eb1b0_0
#   nest-asyncio                           1.4.2-pyhd3eb1b0_0 --> 1.5.1-pyhd3eb1b0_0
#   python                                   3.8.5-h5fd99cc_1 --> 3.8.8-hdbf39b2_5
#
#
#
# Downloading and Extracting Packages
#
# python-3.8.8         | 15.8 MB   |            |   0%
# python-3.8.8         | 15.8 MB   |            |   0%
# python-3.8.8         | 15.8 MB   | 2          |   2%
# python-3.8.8         | 15.8 MB   | #          |  11%
# python-3.8.8         | 15.8 MB   | ######     |  61%
# python-3.8.8         | 15.8 MB   | ########## | 100%
# python-3.8.8         | 15.8 MB   | ########## | 100%
#
# nbclient-0.5.3       | 62 KB     |            |   0%
# nbclient-0.5.3       | 62 KB     | ########## | 100%
# nbclient-0.5.3       | 62 KB     | ########## | 100%
#
# nest-asyncio-1.5.1   | 10 KB     |            |   0%
# nest-asyncio-1.5.1   | 10 KB     | ########## | 100%
# nest-asyncio-1.5.1   | 10 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
conda update --all
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working...
# Warning: 2 possible package resolutions (only showing differing packages):
#   - defaults/noarch::sphinx-3.5.4-pyhd3eb1b0_0, defaults/win-64::docutils-0.16-py38_1
#   - defaults/noarch::sphinx-3.2.1-py_0, defaults/win-64::docutils-0.17-py38haa95532_1done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-build-3.21.4         |   py38haa95532_0         552 KB
#     sphinx-3.5.4               |     pyhd3eb1b0_0         1.1 MB
# Note: you may need to restart the kernel to use updated packages.
#
#     ------------------------------------------------------------
#                                            Total:         1.7 MB
#
# The following packages will be UPDATED:
#
#   conda-build                                 3.20.5-py38_1 --> 3.21.4-py38haa95532_0
#   sphinx                                         3.2.1-py_0 --> 3.5.4-pyhd3eb1b0_0
#
# The following packages will be DOWNGRADED:
#
#   docutils                              0.17-py38haa95532_1 --> 0.16-py38_1
#
#
#
# Downloading and Extracting Packages
#
# conda-build-3.21.4   | 552 KB    |            |   0%
# conda-build-3.21.4   | 552 KB    | 2          |   3%
# conda-build-3.21.4   | 552 KB    | #####2     |  52%
# conda-build-3.21.4   | 552 KB    | ########## | 100%
# conda-build-3.21.4   | 552 KB    | ########## | 100%
#
# sphinx-3.5.4         | 1.1 MB    |            |   0%
# sphinx-3.5.4         | 1.1 MB    | #####1     |  52%
# sphinx-3.5.4         | 1.1 MB    | ########## | 100%
# sphinx-3.5.4         | 1.1 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
conda create --name tf-gpu
